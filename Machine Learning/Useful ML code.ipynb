# %% [markdown]
# #Useful ML code

# %%
# here's useful description of the data counts and distributions of variables
'dataset name'.describe() #shows stats


# To plot pretty figures
## changes font size (unless specifically overridden)
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14) # font size 14
mpl.rc('xtick', labelsize=12) # etc
mpl.rc('ytick', labelsize=12) # etc


##creates a directory and saves the data set wherever the code is ran
# The example below is taken from the data importing of the housing dataset, use chatgpt to explain anything you don't understand.
import os
import tarfile
import urllib.request

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing") #name the file path so datasets/housing
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

housing.info()

import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)
